# %%
import pandas as pd

# Carregar o dataset integrado
df = pd.read_parquet('../data/processed/meddata_integrado_SC_2024_01.parquet')

print(f"Registros: {len(df):,}")
print(f"Colunas: {len(df.columns)}")
print(df.head())
print(df.info())
# Out:
# Registros: 1,903,259
# Colunas: 36
#   codigo_municipio id_hospital codigo_diagnostico data_internacao data_saida  \
# 0           420290     2522411               I214      2023-09-30 2023-10-10
# 1           420290     2522411               I214      2023-09-30 2023-10-10
# 2           420290     2522411               I214      2023-09-30 2023-10-10
# 3           420290     2522411               I214      2023-09-30 2023-10-10
# 4           420290     2522411               I214      2023-09-30 2023-10-10
#
#    valor_procedimento codigo_municipio_paciente  ano_competencia  \
# 0               720.0                    420590             2024
# 1               720.0                    420590             2024
# 2               720.0                    420590             2024
# 3               720.0                    420590             2024
# 4               720.0                    420590             2024
#
#    mes_competencia  dias_internacao  ...  esfera_classificacao  \
# ...
